# %% [markdown]
# Reference: https://github.com/aaron-xichen/pytorch-playground

# %%
# !cd quantize_new && python quantize.py --type resnet18\
--quant_method linear --param_bits 8 --fwd_bits 8 --bn_bits 8 --ngpu 1\
--model_root ./.torch/models/ --input_size 32
# Out:
# Setting GPU: ['0']
# =================FLAGS==================
# type: resnet18
# quant_method: linear
# batch_size: 100
# gpu: ['0']
# ngpu: 1
# seed: 117
# model_root: /home/as6416/vision-model-compression/quantize_new/.torch/models
# data_root: /tmp/public_dataset/pytorch
# logdir: log/default
# input_size: 32
# n_sample: 20
# param_bits: 8
# bn_bits: 8
# fwd_bits: 8
# overflow_rate: 0.0
# ...
# Building and initializing resnet-18 parameters
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Epoch 0/20, Acc=0.4229
# Epoch 1/20, Acc=0.5072
# Epoch 2/20, Acc=0.5818
# Epoch 3/20, Acc=0.5975
# Epoch 4/20, Acc=0.6567
# Epoch 5/20, Acc=0.6712
# Epoch 6/20, Acc=0.7070
# Epoch 7/20, Acc=0.7069
# Epoch 8/20, Acc=0.6974
# Epoch 9/20, Acc=0.7077
# Epoch 10/20, Acc=0.7380
# Epoch 11/20, Acc=0.7529
# Epoch 12/20, Acc=0.7523
# Epoch 13/20, Acc=0.7646
# Epoch 14/20, Acc=0.7824
# ...

# %%
# !cd quantize_new && python quantize.py --type resnet18\
--quant_method linear --param_bits 32 --fwd_bits 32 --bn_bits 32 --ngpu 1\
--model_root ./.torch/models/ --input_size 32
# Out:
# Setting GPU: ['0']
# =================FLAGS==================
# type: resnet18
# quant_method: linear
# batch_size: 100
# gpu: ['0']
# ngpu: 1
# seed: 117
# model_root: /home/as6416/vision-model-compression/quantize_new/.torch/models
# data_root: /tmp/public_dataset/pytorch
# logdir: log/default
# input_size: 32
# n_sample: 20
# param_bits: 32
# bn_bits: 32
# fwd_bits: 32
# overflow_rate: 0.0
# ...
# Building and initializing resnet-18 parameters
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Epoch 0/20, Acc=0.4033
# Epoch 1/20, Acc=0.4720
# Epoch 2/20, Acc=0.5698
# Epoch 3/20, Acc=0.5821
# Epoch 4/20, Acc=0.6362
# Epoch 5/20, Acc=0.6482
# Epoch 6/20, Acc=0.6752
# Epoch 7/20, Acc=0.7023
# Epoch 8/20, Acc=0.6931
# Epoch 9/20, Acc=0.7243
# Epoch 10/20, Acc=0.7153
# Epoch 11/20, Acc=0.7332
# Epoch 12/20, Acc=0.7409
# Epoch 13/20, Acc=0.7183
# ...

# %%
# !cd quantize_new && python quantize.py --type resnet18\
--quant_method linear --param_bits 16 --fwd_bits 16 --bn_bits 16 --ngpu 1\
--model_root ./.torch/models/ --input_size 32
# Out:
# Setting GPU: ['0']
# =================FLAGS==================
# type: resnet18
# quant_method: linear
# batch_size: 100
# gpu: ['0']
# ngpu: 1
# seed: 117
# model_root: /home/as6416/vision-model-compression/quantize_new/.torch/models
# data_root: /tmp/public_dataset/pytorch
# logdir: log/default
# input_size: 32
# n_sample: 20
# param_bits: 16
# bn_bits: 16
# fwd_bits: 16
# overflow_rate: 0.0
# ...
# Building and initializing resnet-18 parameters
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Epoch 0/20, Acc=0.3757
# Epoch 1/20, Acc=0.4822
# Epoch 2/20, Acc=0.5423
# Epoch 3/20, Acc=0.5771
# Epoch 4/20, Acc=0.6394
# Epoch 5/20, Acc=0.6477
# Epoch 6/20, Acc=0.6843
# Epoch 7/20, Acc=0.6854
# Epoch 8/20, Acc=0.7100
# Epoch 9/20, Acc=0.7223
# Epoch 10/20, Acc=0.7266
# Epoch 11/20, Acc=0.7414
# Epoch 12/20, Acc=0.7535
# Epoch 13/20, Acc=0.7360
# ...

# %%
# !cd quantize_new && python quantize.py --type resnet18\
--quant_method linear --param_bits 8 --fwd_bits 8 --bn_bits 10 --ngpu 1\
--model_root ./.torch/models/ --input_size 32
# Out:
# Setting GPU: ['0']
# =================FLAGS==================
# type: resnet18
# quant_method: linear
# batch_size: 100
# gpu: ['0']
# ngpu: 1
# seed: 117
# model_root: /home/as6416/vision-model-compression/quantize_new/.torch/models
# data_root: /tmp/public_dataset/pytorch
# logdir: log/default
# input_size: 32
# n_sample: 20
# param_bits: 8
# bn_bits: 10
# fwd_bits: 8
# overflow_rate: 0.0
# ...
# Building and initializing resnet-18 parameters
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Epoch 0/20, Acc=0.4165
# Epoch 1/20, Acc=0.4981
# Epoch 2/20, Acc=0.5507
# Epoch 3/20, Acc=0.5617
# Epoch 4/20, Acc=0.6342
# Epoch 5/20, Acc=0.6424
# Epoch 6/20, Acc=0.6891
# Epoch 7/20, Acc=0.6926
# Epoch 8/20, Acc=0.7208
# Epoch 9/20, Acc=0.7252
# Epoch 10/20, Acc=0.7326
# Epoch 11/20, Acc=0.7353
# Epoch 12/20, Acc=0.7453
# Epoch 13/20, Acc=0.7527
# Epoch 14/20, Acc=0.7611
# ...

# %%
# !cd quantize_new && python quantize.py --type resnet18\
--quant_method linear --param_bits 8 --fwd_bits 16 --bn_bits 10 --ngpu 1\
--model_root ./.torch/models/ --input_size 32
# Out:
# Setting GPU: ['0']
# =================FLAGS==================
# type: resnet18
# quant_method: linear
# batch_size: 100
# gpu: ['0']
# ngpu: 1
# seed: 117
# model_root: /home/as6416/vision-model-compression/quantize_new/.torch/models
# data_root: /tmp/public_dataset/pytorch
# logdir: log/default
# input_size: 32
# n_sample: 20
# param_bits: 8
# bn_bits: 10
# fwd_bits: 16
# overflow_rate: 0.0
# ...
# Building and initializing resnet-18 parameters
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Building CIFAR-10 data loader with 1 workers
# Files already downloaded and verified
# Epoch 0/20, Acc=0.4000
# Epoch 1/20, Acc=0.4842
# Epoch 2/20, Acc=0.5451
# Epoch 3/20, Acc=0.5504
# Epoch 4/20, Acc=0.6245
# Epoch 5/20, Acc=0.6500
# Epoch 6/20, Acc=0.6721
# Epoch 7/20, Acc=0.6926
# Epoch 8/20, Acc=0.6913
# Epoch 9/20, Acc=0.7120
# Epoch 10/20, Acc=0.7265
# Epoch 11/20, Acc=0.7368
# Epoch 12/20, Acc=0.7398
# Epoch 13/20, Acc=0.7553
# Epoch 14/20, Acc=0.7478
# ...
